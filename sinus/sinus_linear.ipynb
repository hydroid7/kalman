# %%
using Distributions, Compat, Plots, Random, CSV, DataFrames, GLM, Printf
plotly()
upscale = 1
default(line = (:line, 0.5, 1, 2), size=(800*upscale,600*upscale))

# %%
include("../KalmanFilter.jl")
import .KalmanFilter
# Out:
# WARNING: replacing module KalmanFilter.

# %%
x = collect(0:1:100)
y = sin.(0.1*x)
plot(x, y, ylim = (-2, 2), label = "Generierte Daten")
# Out:
#     <div id="ede424aa-dd85-4330-8080-5d2c70a50240" style="width:800px;height:600px;"></div>
#     <script>
#     PLOT = document.getElementById('ede424aa-dd85-4330-8080-5d2c70a50240');
# ...

# %%
A = 1 # Zustandsübergangsmatrix
G = 1 # Messabbildung Matrix
Q = 5
R = 5

x̂_0 = 0
# x̂_0 = f(1)
Σ_0 = 0.5

model = KalmanFilter.Kalman(A, Q, G, R, x̂_0, Σ_0)

y_filtered = zeros(length(x))
y_predicted = zeros(length(x))
for (index, value) in enumerate(x)
    y_cur = y[index]
    y_filtered[index] = KalmanFilter.fusion(model, y_cur, true)
    y_predicted[index] = KalmanFilter.predict(model, true)
    #@printf "Step %4d    y_m %.3f    filtered %.3f    predicted %.3f    gain %.3f\n" index y_cur y_filtered[index] y_predicted[index] KalmanFilter.K(model)
end
# Out:
# Fusion:  x̂ 0.091    Σ 0.000    K 0.455
# Predict: x̂ 0.000    Σ 5.455
# Fusion:  x̂ 0.522    Σ 0.052    K 2.609
# Predict: x̂ 0.052    Σ 7.609
# Fusion:  x̂ 0.603    Σ 0.141    K 3.017
# Predict: x̂ 0.141    Σ 8.017
# Fusion:  x̂ 0.616    Σ 0.236    K 3.079
# Predict: x̂ 0.236    Σ 8.079
# Fusion:  x̂ 0.618    Σ 0.331    K 3.089
# Predict: x̂ 0.331    Σ 8.089
# Fusion:  x̂ 0.618    Σ 0.423    K 3.090
# Predict: x̂ 0.423    Σ 8.090
# Fusion:  x̂ 0.618    Σ 0.510    K 3.090
# Predict: x̂ 0.510    Σ 8.090
# Fusion:  x̂ 0.618    Σ 0.593    K 3.090
# Predict: x̂ 0.593    Σ 8.090
# Fusion:  x̂ 0.618    Σ 0.670    K 3.090
# Predict: x̂ 0.670    Σ 8.090
# Fusion:  x̂ 0.618    Σ 0.740    K 3.090
# Predict: x̂ 0.740    Σ 8.090
# Fusion:  x̂ 0.618    Σ 0.803    K 3.090
# Predict: x̂ 0.803    Σ 8.090
# Fusion:  x̂ 0.618    Σ 0.857    K 3.090
# Predict: x̂ 0.857    Σ 8.090
# Fusion:  x̂ 0.618    Σ 0.904    K 3.090
# Predict: x̂ 0.904    Σ 8.090
# Fusion:  x̂ 0.618    Σ 0.941    K 3.090
# ...

# %%
plot(x, y_predicted, label = "Predicted")
plot!(x, y_filtered, label = "Filtered", linestyle=:dash)
plot!(x, y, label = "Ground Thruth", linestyle=:dot)
# Out:
#     <div id="a36c6edd-21dd-4253-ac5a-67690261b54e" style="width:800px;height:600px;"></div>
#     <script>
#     PLOT = document.getElementById('a36c6edd-21dd-4253-ac5a-67690261b54e');
# ...
